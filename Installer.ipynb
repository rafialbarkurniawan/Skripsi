# %%
# Upgrade pip dulu
# !pip install --upgrade pip

# Library dasar
# !pip install pandas==2.1.4 numpy==1.26.4 matplotlib==3.8.2

# NLP Bahasa Indonesia
# !pip install Sastrawi==1.0.1 nltk==3.8.1

# Scraping
# !pip install google-play-scraper==1.2.4

# Machine Learning
# !pip install scikit-learn==1.3.2 hdbscan==0.8.33

# Topic Modeling
# !pip install bertopic==0.16.0 sentence-transformers==2.2.2

# Wordcloud
# !pip install wordcloud==1.9.3
